# %% [markdown]
# # Move up
#
# Exercises the **async** faro pipeline end-to-end on the Moench, modelled on the
# random-stim experiment but with the **region-percentage** stimulator
# (`StimPercentageOfCell`) from the demo notebook, which illuminates the top
# *percentage* of each segmented cell.
#
# - **Imaging:** red (`mScarlet3`, ERK-KTR reporter) + farred (`miRFP`, PIP).
# - **Stim == ref channel:** `CyanStim` is used for both stimulation and the
#   reference/optocheck readout.
# - **Segmentation:** Cellpose 4 (channel 0). **Tracking:** motile.
# - **Phases (single RTMSequence):** baseline → stim → baseline (recovery) → ref,
#   via `stim_frames` for the stim block and `ref_frames=[-1]` for the final
#   reference frame.
# - **Timing:** 1 min interval, ~3 s per FOV.
# - **Async run:** `run_experiment` returns a `RunHandle`; the
#   `ExperimentStatusWidget` mirrors/steers it live; background DMD calibration.
#
# > **Storage note:** this writes OME-Zarr to `path` below. The `init_stream`
# > SMB fix (PR #12) is **not** on this `move-up` branch — if you hit
# > `PermissionError [WinError 5]` at init on the `Z:` drive, either store
# > locally or have the storage fix cherry-picked onto this branch.
# >
# > **Env:** run with the cellpose + tracking extras, e.g.
# > `uv sync --extra cellpose --extra tracking` in this worktree.

# %%
import os
import time
import numpy as np
import pandas as pd

import napari
from napari_micromanager import MainWindow
import pymmcore_plus

from faro.microscope.pertzlab.moench import Moench
from faro.core.data_structures import (
    Channel,
    PowerChannel,
    RTMSequence,
    SegmentationMethod,
    combine,
    wait,
)
from faro.core.pipeline import ImageProcessingPipeline
from faro.core.controller import Controller
from faro.core.writers import OmeZarrWriter
import faro.core.utils as utils

from faro.segmentation.cellpose_v4 import CellposeV4
from faro.tracking.motile_tracker import TrackerMotile
from faro.feature_extraction.erk_ktr import FE_ErkKtr
from faro.stimulation.percentage_of_cell import StimUp

from faro.widgets import ExperimentStatusWidget

# %% [markdown]
# ## Microscope + napari

# %%
mic = Moench(None)
mic.mmc.setChannelGroup("TTL_ERK")

# %%
# Open napari with the napari-micromanager widget bound to the scope's core.
# Use the MDA widget to pick the FOV positions for generate_fov_positions below.
viewer = napari.Viewer()
mm_wdg = MainWindow(viewer, mmcore=mic.mmc)
viewer.window.add_dock_widget(mm_wdg)

# %% [markdown]
# ## Channels

# %%
# Stimulation channel -- ALSO the reference channel (ref == stim): the
# optogenetic-tool readout is acquired in the same channel that drives stim.
stim_channel = PowerChannel(config="CyanStim", exposure=200, group="TTL_ERK", power=25)

# Imaging channels -- order matters: channel 0 is the one cellpose segments.
imaging_channels = (
    PowerChannel(config="mScarlet3", exposure=200, group="TTL_ERK", power=20),  # red    (ERK-KTR reporter)
    PowerChannel(config="miRFP",     exposure=350, group="TTL_ERK", power=100),  # farred (PIP)
)

ref_channel = PowerChannel(config="mCitrine", exposure=400, group="TTL_ERK", power=80)

# %%
# DMD calibration runs on a background thread (background=True default), so
# napari keeps streaming the live preview while it calibrates.
mic.dmd.affine = None
pymmcore_plus.configure_logging(stderr_level="CRITICAL")
mic.calibrate_dmd(calibration_channel=stim_channel, verbose=True, radius=4, exposure=20)
# Or reuse a saved calibration instead of recalibrating:
# mic.dmd.affine = np.load("affine.npy")

# %% [markdown]
# ## Experiment config: baseline → stim → baseline → ref

# %%
# --- timing ----------------------------------------------------------------
INTERVAL_S     = 3*60      # 1 min between timepoints
TIME_PER_FOV_S = 5.0     # ~3 s to image one FOV (staggers per-FOV start times)

# --- phases ----------------------------------------------------------------
N_BASELINE = 1           # baseline imaging frames (pre-stim)
N_STIM     = 240*2           # stim frames (region-percentage stim fires)
N_RECOVERY = 0           # baseline imaging frames (post-stim recovery)
N_REF      = 1           # final reference-acquisition frame
N_FRAMES   = N_BASELINE + N_STIM + N_RECOVERY + N_REF

STIM_FRAMES = list(range(N_BASELINE, N_BASELINE + N_STIM))   # contiguous stim block
#REF_FRAMES  = [0, -1]                                           # last frame = reference
REF_FRAMES  = [-1]  
# Fraction of each cell to stimulate (top region) -- read by StimPercentageOfCell
# from event metadata; default in the stimulator is 0.3 if omitted.
STIM_CELL_PERCENTAGE = 0.2

# --- storage ---------------------------------------------------------------
# See the storage note at the top re: SMB / PR #12.
base_path = r"C:\Users\lh21x018\Desktop\temp"
base_path = r"Z:\lhinder\data\rtm_mm_data\exp_501"
# base_path = r"Z:\lhinder\data\rtm_mm_data\exp_move_up_test"
experiment_name = "move_up_20X"
path = os.path.join(base_path, experiment_name)

# %% [markdown]
# ## Pipeline: CellposeV4 + motile + region-percentage stim

# %%
segmentators = [
    SegmentationMethod(
        name="labels",
        segmentation_class=CellposeV4(gamma=0.3),   # Cellpose 4
        use_channel=[0,1],                      # segment the red/farred channels
        save_tracked=True,
    )
]
stimulator = StimUp()          # stimulates the top % of each cell
feature_extractor = FE_ErkKtr("labels")      # per-cell features (feeds the tracker)
tracker = TrackerMotile(search_range=70)     # motile tracking

pipeline = ImageProcessingPipeline(
    storage_path=path,
    segmentators=segmentators,
    feature_extractor=feature_extractor,
    tracker=tracker,
    stimulator=stimulator,
)

writer = OmeZarrWriter(storage_path=path)
ctrl = Controller(mic, pipeline, writer=writer)
# Out:
# Directory Z:\lhinder\data\rtm_mm_data\exp_501\move_up_20X\tracks already exists

# %% [markdown]
# ## Build the acquisition

# %%
# Pick the FOV positions in the napari-mm MDA widget first, then run this cell.
fov_positions = utils.generate_fov_positions(mic, viewer=viewer)
print(len(fov_positions))
phase = RTMSequence(
    time_plan={"interval": INTERVAL_S, "loops": N_FRAMES},
    stage_positions=fov_positions,
    channels=imaging_channels,
    stim_channels=(stim_channel,),
    stim_frames=STIM_FRAMES,
    ref_channels=(ref_channel,),    # ref == stim channel
    ref_frames=REF_FRAMES,
    rtm_metadata={
        "phase_name": "region_percentage_stim",
        "phase_id": 0,   # pipeline names tracks parquet from this -- required
        "stim_cell_percentage": STIM_CELL_PERCENTAGE,
        "treatment_name": "move_up_stim",
        "stim_fov": None
    },
)
# Out:
# 32

# %%
events = utils.apply_fov_batching(
    phase, time_per_fov=TIME_PER_FOV_S, offset_min_start_time=True
)

# %%
events
# Out:
# [RTMEvent(index={'t': 0, 'p': 0}, min_start_time=0.0, x_pos=32395.2, y_pos=-8229.7, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 1}, min_start_time=5.0, x_pos=32370.0, y_pos=-7605.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 2}, min_start_time=10.0, x_pos=32517.0, y_pos=-9205.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 3}, min_start_time=15.0, x_pos=30743.1, y_pos=-9312.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 4}, min_start_time=20.0, x_pos=13986.7, y_pos=-8098.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 5}, min_start_time=25.0, x_pos=11163.5, y_pos=-8384.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 6}, min_start_time=30.0, x_pos=11185.7, y_pos=-9585.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 7}, min_start_time=35.0, x_pos=11833.9, y_pos=-11136.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 8}, min_start_time=40.0, x_pos=-4202.7, y_pos=-11034.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 9}, min_start_time=45.0, x_pos=-4202.7, y_pos=-8867.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 10}, min_start_time=50.0, x_pos=-5489.1, y_pos=-9062.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 11}, min_start_time=55.0, x_pos=-7027.3, y_pos=-8949.1, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 12}, min_start_time=60.0, x_pos=-26186.4, y_pos=-9148.7, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 13}, min_start_time=65.0, x_pos=-26186.4, y_pos=-9980.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 14}, min_start_time=70.0, x_pos=-26186.4, y_pos=-12176.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 15}, min_start_time=75.0, x_pos=-28474.6, y_pos=-13030.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 16}, min_start_time=80.0, x_pos=-25811.6, y_pos=7854.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 17}, min_start_time=85.0, x_pos=-25233.9, y_pos=7747.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 18}, min_start_time=90.0, x_pos=-25377.2, y_pos=6291.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 19}, min_start_time=95.0, x_pos=-27564.5, y_pos=5944.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 20}, min_start_time=100.0, x_pos=-4379.9, y_pos=9997.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 21}, min_start_time=105.0, x_pos=-3554.3, y_pos=9624.9, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 22}, min_start_time=110.0, x_pos=-5353.3, y_pos=8608.2, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 23}, min_start_time=115.0, x_pos=-7087.6, y_pos=7929.8, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 24}, min_start_time=120.0, x_pos=11535.2, y_pos=9200.1, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 25}, min_start_time=125.0, x_pos=12331.2, y_pos=9418.9, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 26}, min_start_time=130.0, x_pos=11983.0, y_pos=13614.7, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 27}, min_start_time=135.0, x_pos=10912.3, y_pos=13592.2, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 28}, min_start_time=140.0, x_pos=31804.8, y_pos=7354.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 29}, min_start_time=145.0, x_pos=32825.5, y_pos=7355.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 30}, min_start_time=150.0, x_pos=32845.8, y_pos=5008.8, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 0, 'p': 31}, min_start_time=155.0, x_pos=33757.0, y_pos=4831.2, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100))),
#  RTMEvent(index={'t': 1, 'p': 0}, min_start_time=180.0, x_pos=32395.2, y_pos=-8229.7, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 1}, min_start_time=185.0, x_pos=32370.0, y_pos=-7605.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 2}, min_start_time=190.0, x_pos=32517.0, y_pos=-9205.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 3}, min_start_time=195.0, x_pos=30743.1, y_pos=-9312.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 4}, min_start_time=200.0, x_pos=13986.7, y_pos=-8098.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 5}, min_start_time=205.0, x_pos=11163.5, y_pos=-8384.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 6}, min_start_time=210.0, x_pos=11185.7, y_pos=-9585.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 7}, min_start_time=215.0, x_pos=11833.9, y_pos=-11136.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 8}, min_start_time=220.0, x_pos=-4202.7, y_pos=-11034.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 9}, min_start_time=225.0, x_pos=-4202.7, y_pos=-8867.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 10}, min_start_time=230.0, x_pos=-5489.1, y_pos=-9062.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 11}, min_start_time=235.0, x_pos=-7027.3, y_pos=-8949.1, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 12}, min_start_time=240.0, x_pos=-26186.4, y_pos=-9148.7, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 13}, min_start_time=245.0, x_pos=-26186.4, y_pos=-9980.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 14}, min_start_time=250.0, x_pos=-26186.4, y_pos=-12176.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 15}, min_start_time=255.0, x_pos=-28474.6, y_pos=-13030.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 16}, min_start_time=260.0, x_pos=-25811.6, y_pos=7854.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 17}, min_start_time=265.0, x_pos=-25233.9, y_pos=7747.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 18}, min_start_time=270.0, x_pos=-25377.2, y_pos=6291.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 19}, min_start_time=275.0, x_pos=-27564.5, y_pos=5944.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 20}, min_start_time=280.0, x_pos=-4379.9, y_pos=9997.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 21}, min_start_time=285.0, x_pos=-3554.3, y_pos=9624.9, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 22}, min_start_time=290.0, x_pos=-5353.3, y_pos=8608.2, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 23}, min_start_time=295.0, x_pos=-7087.6, y_pos=7929.8, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 24}, min_start_time=300.0, x_pos=11535.2, y_pos=9200.1, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 25}, min_start_time=305.0, x_pos=12331.2, y_pos=9418.9, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 26}, min_start_time=310.0, x_pos=11983.0, y_pos=13614.7, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 27}, min_start_time=315.0, x_pos=10912.3, y_pos=13592.2, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 28}, min_start_time=320.0, x_pos=31804.8, y_pos=7354.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 29}, min_start_time=325.0, x_pos=32825.5, y_pos=7355.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 30}, min_start_time=330.0, x_pos=32845.8, y_pos=5008.8, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 1, 'p': 31}, min_start_time=335.0, x_pos=33757.0, y_pos=4831.2, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 0}, min_start_time=360.0, x_pos=32395.2, y_pos=-8229.7, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 1}, min_start_time=365.0, x_pos=32370.0, y_pos=-7605.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 2}, min_start_time=370.0, x_pos=32517.0, y_pos=-9205.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 3}, min_start_time=375.0, x_pos=30743.1, y_pos=-9312.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 4}, min_start_time=380.0, x_pos=13986.7, y_pos=-8098.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 5}, min_start_time=385.0, x_pos=11163.5, y_pos=-8384.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 6}, min_start_time=390.0, x_pos=11185.7, y_pos=-9585.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 7}, min_start_time=395.0, x_pos=11833.9, y_pos=-11136.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 8}, min_start_time=400.0, x_pos=-4202.7, y_pos=-11034.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 9}, min_start_time=405.0, x_pos=-4202.7, y_pos=-8867.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 10}, min_start_time=410.0, x_pos=-5489.1, y_pos=-9062.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 11}, min_start_time=415.0, x_pos=-7027.3, y_pos=-8949.1, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 12}, min_start_time=420.0, x_pos=-26186.4, y_pos=-9148.7, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 13}, min_start_time=425.0, x_pos=-26186.4, y_pos=-9980.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 14}, min_start_time=430.0, x_pos=-26186.4, y_pos=-12176.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 15}, min_start_time=435.0, x_pos=-28474.6, y_pos=-13030.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 16}, min_start_time=440.0, x_pos=-25811.6, y_pos=7854.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 17}, min_start_time=445.0, x_pos=-25233.9, y_pos=7747.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 18}, min_start_time=450.0, x_pos=-25377.2, y_pos=6291.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 19}, min_start_time=455.0, x_pos=-27564.5, y_pos=5944.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 20}, min_start_time=460.0, x_pos=-4379.9, y_pos=9997.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 21}, min_start_time=465.0, x_pos=-3554.3, y_pos=9624.9, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 22}, min_start_time=470.0, x_pos=-5353.3, y_pos=8608.2, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 23}, min_start_time=475.0, x_pos=-7087.6, y_pos=7929.8, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 24}, min_start_time=480.0, x_pos=11535.2, y_pos=9200.1, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 25}, min_start_time=485.0, x_pos=12331.2, y_pos=9418.9, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 26}, min_start_time=490.0, x_pos=11983.0, y_pos=13614.7, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 27}, min_start_time=495.0, x_pos=10912.3, y_pos=13592.2, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 28}, min_start_time=500.0, x_pos=31804.8, y_pos=7354.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 29}, min_start_time=505.0, x_pos=32825.5, y_pos=7355.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 30}, min_start_time=510.0, x_pos=32845.8, y_pos=5008.8, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 2, 'p': 31}, min_start_time=515.0, x_pos=33757.0, y_pos=4831.2, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 3, 'p': 0}, min_start_time=540.0, x_pos=32395.2, y_pos=-8229.7, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 3, 'p': 1}, min_start_time=545.0, x_pos=32370.0, y_pos=-7605.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 3, 'p': 2}, min_start_time=550.0, x_pos=32517.0, y_pos=-9205.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 3, 'p': 3}, min_start_time=555.0, x_pos=30743.1, y_pos=-9312.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 3, 'p': 4}, min_start_time=560.0, x_pos=13986.7, y_pos=-8098.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 3, 'p': 5}, min_start_time=565.0, x_pos=11163.5, y_pos=-8384.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 3, 'p': 6}, min_start_time=570.0, x_pos=11185.7, y_pos=-9585.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 3, 'p': 7}, min_start_time=575.0, x_pos=11833.9, y_pos=-11136.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
# ...
#  RTMEvent(index={'t': 30, 'p': 8}, min_start_time=5440.0, x_pos=-4202.7, y_pos=-11034.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 9}, min_start_time=5445.0, x_pos=-4202.7, y_pos=-8867.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 10}, min_start_time=5450.0, x_pos=-5489.1, y_pos=-9062.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 11}, min_start_time=5455.0, x_pos=-7027.3, y_pos=-8949.1, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 12}, min_start_time=5460.0, x_pos=-26186.4, y_pos=-9148.7, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 13}, min_start_time=5465.0, x_pos=-26186.4, y_pos=-9980.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 14}, min_start_time=5470.0, x_pos=-26186.4, y_pos=-12176.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 15}, min_start_time=5475.0, x_pos=-28474.6, y_pos=-13030.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 16}, min_start_time=5480.0, x_pos=-25811.6, y_pos=7854.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 17}, min_start_time=5485.0, x_pos=-25233.9, y_pos=7747.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 18}, min_start_time=5490.0, x_pos=-25377.2, y_pos=6291.4, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 19}, min_start_time=5495.0, x_pos=-27564.5, y_pos=5944.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 20}, min_start_time=5500.0, x_pos=-4379.9, y_pos=9997.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 21}, min_start_time=5505.0, x_pos=-3554.3, y_pos=9624.9, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 22}, min_start_time=5510.0, x_pos=-5353.3, y_pos=8608.2, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 23}, min_start_time=5515.0, x_pos=-7087.6, y_pos=7929.8, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 24}, min_start_time=5520.0, x_pos=11535.2, y_pos=9200.1, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 25}, min_start_time=5525.0, x_pos=12331.2, y_pos=9418.9, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 26}, min_start_time=5530.0, x_pos=11983.0, y_pos=13614.7, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 27}, min_start_time=5535.0, x_pos=10912.3, y_pos=13592.2, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 28}, min_start_time=5540.0, x_pos=31804.8, y_pos=7354.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 29}, min_start_time=5545.0, x_pos=32825.5, y_pos=7355.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 30}, min_start_time=5550.0, x_pos=32845.8, y_pos=5008.8, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 30, 'p': 31}, min_start_time=5555.0, x_pos=33757.0, y_pos=4831.2, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 31, 'p': 0}, min_start_time=5580.0, x_pos=32395.2, y_pos=-8229.7, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 31, 'p': 1}, min_start_time=5585.0, x_pos=32370.0, y_pos=-7605.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 31, 'p': 2}, min_start_time=5590.0, x_pos=32517.0, y_pos=-9205.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 31, 'p': 3}, min_start_time=5595.0, x_pos=30743.1, y_pos=-9312.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 31, 'p': 4}, min_start_time=5600.0, x_pos=13986.7, y_pos=-8098.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 31, 'p': 5}, min_start_time=5605.0, x_pos=11163.5, y_pos=-8384.0, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 31, 'p': 6}, min_start_time=5610.0, x_pos=11185.7, y_pos=-9585.3, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  RTMEvent(index={'t': 31, 'p': 7}, min_start_time=5615.0, x_pos=11833.9, y_pos=-11136.5, metadata={'phase_name': 'region_percentage_stim', 'phase_id': 0, 'stim_cell_percentage': 0.2, 'treatment_name': 'move_up_stim', 'stim_fov': None}, channels=(PowerChannel(config='mScarlet3', exposure=200.0, group='TTL_ERK', power=20), PowerChannel(config='miRFP', exposure=350.0, group='TTL_ERK', power=100)), stim_channels=(PowerChannel(config='CyanStim', exposure=200, group='TTL_ERK', power=25),)),
#  ...]

# %%
ctrl.validate_events(events)
# Out:
# True

# %% [markdown]
# ## Validate + dock the status widget

# %%
handle = ctrl._current_handle

# %%
handle.cancel()

# %%
# Mirrors and steers the current run (state, event strip, FOV map, lag,
# pause/stop); re-binds automatically on each run_experiment.
status_wdg = ExperimentStatusWidget(ctrl)
viewer.window.add_dock_widget(status_wdg, name="Experiment status")

# %% [markdown]
# ## Run (async)

# %%
# Returns a RunHandle immediately and drives the MDA on a worker thread.
# Watch the status widget, or use handle.status() / handle.pause() /
# handle.resume() / handle.cancel(). stim_mode="current": stim fires after
# imaging frame t using frame t's segmentation mask.
handle = ctrl.run_experiment(events, stim_mode="previous")

# %%
handle.status()
# Out:
# RunStatus(state='running', current_event_index=None, current_fov=None, n_events_total=15424, n_events_consumed=0, n_events_acquired=0, n_frames_received=0, started_at=None, finished_at=None, last_frame_wallclock=None, lag_ms=None, wait_remaining_s=None, pipeline_inflight=0, storage_queue_depth=0, background_errors=(), fatal_error=None)

# %% [markdown]
# ## Finish + post-process

# %%
# Blocks until the run finishes, flushes the pipeline, and closes the zarr store.
ctrl.finish_experiment()

# Merge per-FOV tracks into a single exp_data.parquet for analysis.
utils.generate_exp_data_from_tracks(path)
